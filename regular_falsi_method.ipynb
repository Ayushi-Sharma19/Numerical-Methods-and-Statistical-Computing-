# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi-Sharma19/Numerical-Methods-and-Statistical-Computing-/blob/main/regular_falsi_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x):
    return eval(expression)

def regula_falsi(a, b, tol, max_iter):
    if f(a) * f(b) >= 0:
        return "Invalid interval. The function must have opposite signs at a and b."

    for _ in range(max_iter):
        c = b - (f(b) * (b - a)) / (f(b) - f(a))
        if abs(f(c)) < tol:
            return c
        if f(a) * f(c) < 0:
            b = c
        else:
            a = c
    return "Solution did not converge."

expression = input("Enter the function f(x): ")
a = float(input("Enter the lower bound (a): "))
b = float(input("Enter the upper bound (b): "))
tol = float(input("Enter the tolerance: "))
max_iter = int(input("Enter the maximum number of iterations: "))

result = regula_falsi(a, b, tol, max_iter)
print("Root:", result)
# Out:
# Enter the function f(x): (x*x*x)-4*x-9
# Enter the lower bound (a): 2
# Enter the upper bound (b): 3
# Enter the tolerance: 10
# Enter the maximum number of iterations: 100
# Root: 2.6
